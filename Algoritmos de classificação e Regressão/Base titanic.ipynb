# %%
#Autor: João Victor

# %%
# Importando as bibliotecas do Python
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('titanic.csv')

# %%
#primeiras linhas
df.head(10)
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5     1.0       1.0                              Anderson, Mr. Harry    male
# 6     1.0       1.0                Andrews, Miss. Kornelia Theodosia  female
# 7     1.0       0.0                           Andrews, Mr. Thomas Jr    male
# 8     1.0       1.0    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9     1.0       0.0                          Artagaveytia, Mr. Ramon    male
#
#        age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# ...

# %%
#últimas linhas
df.tail(10)
# Out:
#       pclass  survived                                     name     sex   age  \
# 1300     3.0       1.0  Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.0
# 1301     3.0       0.0                     Youseff, Mr. Gerious    male  45.5
# 1302     3.0       0.0                        Yousif, Mr. Wazli    male   NaN
# 1303     3.0       0.0                    Yousseff, Mr. Gerious    male   NaN
# 1304     3.0       0.0                     Zabour, Miss. Hileni  female  14.5
# 1305     3.0       0.0                    Zabour, Miss. Thamine  female   NaN
# 1306     3.0       0.0                Zakarian, Mr. Mapriededer    male  26.5
# 1307     3.0       0.0                      Zakarian, Mr. Ortin    male  27.0
# 1308     3.0       0.0                       Zimmerman, Mr. Leo    male  29.0
# 1309     NaN       NaN                                      NaN     NaN   NaN
#
#       sibsp  parch  ticket     fare cabin embarked boat   body home.dest
# ...

# %%
# Listandos os tipos de dados de todas as colunas do DataFrame
df.dtypes
# Out:
# pclass       float64
# survived     float64
# name          object
# sex           object
# age          float64
# sibsp        float64
# parch        float64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
# Listando os nomes das colunas
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
# Listando os rótulos das linhas e colunas
df.axes
# Out:
# [RangeIndex(start=0, stop=1310, step=1),
#  Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#         'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#        dtype='object')]

# %%
# Número de dimensões
df.ndim
# Out:
# 2

# %%
# Total de elementos no Data Frame
df.size
# Out:
# 18340

# %%
# Número de Linhas e Colunas
df.shape
# Out:
# (1310, 14)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     NaN       NaN                                              NaN
#
# ...

# %%
df.mean()
# Out:
# C:\Users\Joaol\AppData\Local\Temp/ipykernel_49784/3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# pclass        2.294882
# survived      0.381971
# age          29.881135
# sibsp         0.498854
# parch         0.385027
# fare         33.295479
# body        160.809917
# dtype: float64

# %%
df.std()
# Out:
# C:\Users\Joaol\AppData\Local\Temp/ipykernel_49784/3390915376.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# pclass       0.837836
# survived     0.486055
# age         14.413500
# sibsp        1.041658
# parch        0.865560
# fare        51.758668
# body        97.696922
# dtype: float64

# %%
df_sex = df.groupby('sex')

# %%
df.sex.head(5)
# Out:
# 0    female
# 1      male
# 2    female
# 3      male
# 4    female
# Name: sex, dtype: object

# %%
df.age.describe()
# Out:
# count    1046.000000
# mean       29.881135
# std        14.413500
# min         0.166700
# 25%        21.000000
# 50%        28.000000
# 75%        39.000000
# max        80.000000
# Name: age, dtype: float64

# %%
df.age.count()
# Out:
# 1046

# %%
df.age.mean()
# Out:
# 29.8811345124283

# %%
df_survived = df.groupby('survived')

# %%
df_survived.mean()
# Out:
#             pclass        age     sibsp     parch       fare        body
# survived
# 0.0       2.500618  30.545369  0.521632  0.328801  23.353831  160.809917
# 1.0       1.962000  28.918228  0.462000  0.476000  49.361184         NaN

# %%
df.groupby('sex')[['age']].mean()
# Out:
#               age
# sex
# female  28.687071
# male    30.585233

# %%
df.groupby(['sex', 'survived'], sort=False)[['age']].mean()
# Out:
#                        age
# sex    survived
# female 1.0       29.815354
# male   1.0       26.977778
# female 0.0       25.255208
# male   0.0       31.516412

# %%
df_survived = df[ df['survived'] == 1]

# %%
df_survived.tail(20)
# Out:
#       pclass  survived                                               name  \
# 1216     3.0       1.0                                 Smyth, Miss. Julia
# 1223     3.0       1.0                    Stanley, Miss. Amy Zillah Elsie
# 1228     3.0       1.0                                 Stranden, Mr. Juho
# 1232     3.0       1.0                     Sunderland, Mr. Victor Francis
# 1233     3.0       1.0                          Sundman, Mr. Johan Julian
# 1236     3.0       1.0                         Svensson, Mr. Johan Cervin
# 1238     3.0       1.0                         Tenglin, Mr. Gunnar Isidor
# 1240     3.0       1.0                    Thomas, Master. Assad Alexander
# 1244     3.0       1.0          Thomas, Mrs. Alexander (Thamine "Thelma")
# 1247     3.0       1.0  Thorneycroft, Mrs. Percival (Florence Kate White)
# 1254     3.0       1.0                       Tornquist, Mr. William Henry
# 1256     3.0       1.0                     Touma, Master. Georges Youssef
# ...

# %%
df_survived.shape
# Out:
# (500, 14)

# %%
df.groupby(['pclass'])['survived'].count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='pclass'>

# %%
ax = sns.barplot(x='pclass',y ='survived', hue='sex', data=df, estimator=len)

# %%
sns.violinplot(x = "age", data=df)
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.swarmplot(x='survived',y='age', data=df)
# Out:
# C:\Users\Joaol\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 16.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Joaol\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %%
sns.pairplot(df)

# %%
sns.jointplot(x='pclass', y='survived', data=df)

# %%
from scipy import stats
df_w = df[ df['sex'] == 'Female']['age']
df_m = df[ df['sex'] == 'Male']['age']
stats.ttest_ind(df_w, df_m)
# Out:
# Ttest_indResult(statistic=nan, pvalue=nan)

# %%
sns.jointplot(x='age', y='survived', data=df)
